# %% [markdown]
# # Extract SMILES from ChEMBL24 all compounds dataset and create ECFPs for the entries

# %%
import pandas as pd
from rdkit.Chem import MolFromSmiles, MolToSmiles
from rdkit.Chem.rdMolDescriptors import GetMorganFingerprintAsBitVect

# %% [markdown]
# ### Read data into Pandas dataframe

# %%
path = "../data/ChEMBL24_all_compounds.csv.gz"
data = pd.read_csv(path)
# Out:
# C:\Users\thoma\AppData\Local\conda\conda\envs\playground\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (5,6,7,8,9,11,14,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Print basic information

# %%
data.shape
# Out:
# (1739196, 20)

# %%
data.columns
# Out:
# Index(['ChEMBL_ID', ' Molregno', ' InChIKey', ' SMILES', ' MolWeight',
#        ' AlogP', ' HBAcc', ' HBDonor', ' PSArea', ' RotaBonds', ' Ro3Pass',
#        ' Ro5Viol', ' aPKA', ' bPKA', ' logP', ' logD', ' MolType', ' Aromatic',
#        ' Hatoms', ' QED'],
#       dtype='object')

# %%
data.head()
# Out:
#       ChEMBL_ID   Molregno                      InChIKey  \
# 0    CHEMBL6329          1   OWRSAHYFSSNENM-UHFFFAOYSA-N
# 1    CHEMBL6328          2   ZJYUMURGSZQFMH-UHFFFAOYSA-N
# 2  CHEMBL265667          3   YOMWDCALSDWFSV-UHFFFAOYSA-N
# 3    CHEMBL6362          4   PSOPUAQFGCRDIP-UHFFFAOYSA-N
# 4  CHEMBL267864          5   KEZNSCMBVRNOHO-UHFFFAOYSA-N
#
#                                            SMILES   MolWeight  AlogP  HBAcc  \
# 0       Cc1cc(ccc1C(=O)c2ccccc2Cl)N3N=CC(=O)NC3=O      341.75   2.11      5
# 1    Cc1cc(ccc1C(=O)c2ccc(cc2)C#N)N3N=CC(=O)NC3=O      332.32   1.33      6
# 2   Cc1cc(cc(C)c1C(O)c2ccc(Cl)cc2)N3N=CC(=O)NC3=O      357.80   2.27      5
# 3       Cc1ccc(cc1)C(=O)c2ccc(cc2)N3N=CC(=O)NC3=O      307.31   1.46      5
# 4     Cc1cc(ccc1C(=O)c2ccc(Cl)cc2)N3N=CC(=O)NC3=O      341.75   2.11      5
#
#    HBDonor   PSArea  RotaBonds  Ro3Pass  Ro5Viol   aPKA   bPKA   logP   logD  \
# 0        1    84.82          3        N        0   6.44   None   3.19   2.22
# 1        1   108.61          3        N        0   6.44   None   2.64   1.68
# 2        2    87.98          3        N        0   6.59   0.00   3.04   2.20
# 3        1    84.82          3        N        0   6.12   None   2.98   1.76
# 4        1    84.82          3        N        0   6.44   None   3.97   3.01
#
#     MolType  Aromatic  Hatoms    QED
# 0      ACID         3      24   0.74
# 1      ACID         3      25   0.73
# 2   NEUTRAL         3      25   0.75
# 3      ACID         3      23   0.74
# 4      ACID         3      24   0.74

# %% [markdown]
# ### Extract SMILES from the raw data and convert to ECFP

# %%
def smiles2ecfp(smiles, radius=4, bits=2048):
    mol = MolFromSmiles(smiles)
    if mol is None:
        return ""
    fp = GetMorganFingerprintAsBitVect(mol, radius, nBits=bits)
    return "".join(map(str, list(fp)))

# %%
extracted_data = data[["ChEMBL_ID", " SMILES"]]
extracted_data["ECFP"] = extracted_data[" SMILES"].map(smiles2ecfp)
extracted_data.head()
# Out:
# C:\Users\thoma\AppData\Local\conda\conda\envs\playground\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       ChEMBL_ID                                          SMILES  \
# 0    CHEMBL6329       Cc1cc(ccc1C(=O)c2ccccc2Cl)N3N=CC(=O)NC3=O
# 1    CHEMBL6328    Cc1cc(ccc1C(=O)c2ccc(cc2)C#N)N3N=CC(=O)NC3=O
# 2  CHEMBL265667   Cc1cc(cc(C)c1C(O)c2ccc(Cl)cc2)N3N=CC(=O)NC3=O
# 3    CHEMBL6362       Cc1ccc(cc1)C(=O)c2ccc(cc2)N3N=CC(=O)NC3=O
# 4  CHEMBL267864     Cc1cc(ccc1C(=O)c2ccc(Cl)cc2)N3N=CC(=O)NC3=O
#
#                                                 ECFP
# 0  0100000001000000000000000000000100000000000100...
# 1  0000000001000000000000000000000100100000000100...
# 2  0100000000000000000000000000000000000000000100...
# 3  0000000001000000000000000000000000000000000100...
# 4  0000000001000000000000000000000100000000000100...

# %%
extracted_data.loc[extracted_data["ECFP"]==""]
# Out:
#              ChEMBL_ID                                             SMILES ECFP
# 1070237  CHEMBL1965222     Clp1(Cl)np(Cl)(Cl)np2(NNP(=O)(NN2)Oc3ccccc3)n1
# 1092487  CHEMBL1989375     Clp1(Cl)np(Cl)(Cl)np2(NNP(=S)(NN2)Oc3ccccc3)n1
# 1099106  CHEMBL1996554          N1c2ccccc2p3(c4ccccc14)c5ccccc5nc6ccccc36
# 1108484  CHEMBL2006679   S=P1(NNp2(NN1)np(np(n2)(N3CC3)N4CC4)(N5CC5)N6...
# 1114774  CHEMBL2022084         FC1(F)COp2(OCC1(F)F)np(Cl)(Cl)np(Cl)(Cl)n2
# 1114776  CHEMBL2022086              CC1(C)COp2(OC1)np(Cl)(Cl)np(Cl)(Cl)n2
# 1114777  CHEMBL2022087   Clp1(Cl)np(Nc2ccccc2)(Nc3ccccc3)np4(NCCCN4CCC...
# 1114778  CHEMBL2022088   Clp1(Cl)np(Sc2ccccc2)(Sc3ccccc3)np4(NCCCN4CCC...
# 1115936  CHEMBL2023245   FC1(F)COp2(OCC1(F)F)np(Cl)(Cl)np3(NCCCN3CCCCN...
# 1115937  CHEMBL2023246   FC1(F)COp2(Cl)np(Cl)(OCC1(F)F)np3(NCCCN3CCCCN...
# 1115938  CHEMBL2023247   CC1(C)COp2(OC1)np(Cl)(Cl)np3(NCCCN3CCCCN4CCCN...
# 1115940  CHEMBL2023249   FC1(F)COp2(OCC1(F)F)np34NCCCN3CCCCN5CCCNp5(n2)n4
# 1115941  CHEMBL2023250        CC1(C)COp2(OC1)np34NCCCN3CCCCN5CCCNp5(n2)n4
# 1206996  CHEMBL2272784                                     [Al+3].[PH6-3]
# 1290508  CHEMBL3086632     CCN1CCN(Cc2ccc(F)cc2)p13np(Cl)(Cl)np(Cl)(Cl)n3
# 1290509  CHEMBL3086633   CN1CCCN(Cc2ccc(F)cc2)p13np(np(n3)(N4CCCCC4)N5...
# 1290510  CHEMBL3086634   CN1CCCN(Cc2ccc(F)cc2)p13np(np(n3)(N4CCOCC4)N5...
# 1290511  CHEMBL3086635   CN1CCCN(Cc2ccc(F)cc2)p13np(np(n3)(N4CCC5(CC4)...
# 1290512  CHEMBL3086636   CCN1CCN(Cc2ccc(F)cc2)p13np(np(n3)(N4CCOCC4)N5...
# 1290513  CHEMBL3086637   CCN1CCN(Cc2ccc(F)cc2)p13np(np(n3)(N4CCC5(CC4)...
# 1290514  CHEMBL3086638   CN1CCN(Cc2ccc(F)cc2)p13np(np(n3)(N4CCOCC4)N5C...
# 1290515  CHEMBL3086639   CN1CCN(Cc2ccc(F)cc2)p13np(np(n3)(N4CCC5(CC4)O...
# 1290516  CHEMBL3086640      CN1CCN(Cc2ccc(F)cc2)p13np(Cl)(Cl)np(Cl)(Cl)n3
# 1290517  CHEMBL3086641     CN1CCCN(Cc2ccc(F)cc2)p13np(Cl)(Cl)np(Cl)(Cl)n3
# 1290518  CHEMBL3086642   CN1CCN(Cc2ccc(F)cc2)p13np(np(n3)(N4CCCC4)N5CC...
# 1290519  CHEMBL3086643   CCN1CCN(Cc2ccc(F)cc2)p13np(np(n3)(N4CCCC4)N5C...
# 1290520  CHEMBL3086644   CN1CCCN(Cc2ccc(F)cc2)p13np(np(n3)(N4CCCC4)N5C...
# 1290521  CHEMBL3086645   CN1CCN(Cc2ccc(F)cc2)p13np(np(n3)(N4CCCCC4)N5C...
# 1290522  CHEMBL3086646   CCN1CCN(Cc2ccc(F)cc2)p13np(np(n3)(N4CCCCC4)N5...
# 1640442  CHEMBL3832892   O.CCN1C(=O)c2cccc3c(ccc(C1=O)c23)N4C=C5CN67CC...
# 1640443  CHEMBL3832893   O.CCN1C(=O)c2cccc3c(ccc(C1=O)c23)N4C=C5CN67CC...

# %% [markdown]
# ### Drop the data that the SMILES strings cannot be loaded by RDKit

# %%
extracted_data.drop(extracted_data[extracted_data["ECFP"]==""].index, inplace=True)
extracted_data.shape
# Out:
# C:\Users\thoma\AppData\Local\conda\conda\envs\playground\lib\site-packages\pandas\core\frame.py:3930: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# (1739165, 3)

# %% [markdown]
# ### Write data out

# %%
extracted_data.to_csv("../data/ChEMBL24_smiles_fp.csv")
